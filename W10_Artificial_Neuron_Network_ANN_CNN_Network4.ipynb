# %% [markdown]
# <a href="https://colab.research.google.com/github/blowmeaway1234/Artificial-Intelligence/blob/main/W10_Artificial_Neuron_Network_ANN_CNN_Network4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
folder = '/content/drive/MyDrive/Resize Data/'
for i in range(60):
    plt.subplot(10, 6, i+1)
    filename = folder + '/Danh (' + str(i+1) + ').jpg'
    img = imread(filename)
    plt.imshow(img)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils import load_img,img_to_array
#Folder
folder = '/content/drive/MyDrive/Resize Data/'

#Add list
photos,labels=list(),list()

for file in listdir(folder):
  output=0.0
  if file.startswith('Danh'):
    output=1
  if file.startswith('Dien'):
    output=2
  img = load_img(folder + file)
  photo=img_to_array(img)
  photos.append(photo)
  labels.append(output)
  
photos=asarray(photos)
labels=asarray(labels)

print(photos.shape,labels.shape)
save('Danh_Dien_photos.npg',photo)
save('Danh_Dien_labels.npg',labels)
# Out:
# (120,) (120,)
# <ipython-input-19-b85773d61167>:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   photos=asarray(photos)
