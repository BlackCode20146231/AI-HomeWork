# %% [markdown]
# <a href="https://colab.research.google.com/github/blowmeaway1234/Artificial-Intelligence/blob/main/W7_Machine_Learning_17_3_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mtcars.csv

# %%
import pandas as pd
url ='mtcars.csv'
data = pd.read_csv(url)
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation=data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
# Model Linear Regression
model = linear_model.LinearRegression()
# Teaching Machine
model.fit(X = pd.DataFrame(data['wt']), y = data['mpg'])
print('Hệ số intercept là: ',model.intercept_)
print('Hệ số coefient là: ', model.coef_)
# Out:
# Hệ số intercept là:  37.28512616734204
# Hệ số coefient là:  [-5.34447157]

# %%
model.score(X = pd.DataFrame(data['wt']), y = data['mpg'])
# Out:
# 0.7528327936582646

# %%
y_pred=model.predict(X = pd.DataFrame(data['wt']))
print(y_pred)
# Out:
# [23.28261065 21.9197704  24.88595212 20.10265006 18.90014396 18.79325453
#  18.20536265 20.23626185 20.45004071 18.90014396 18.90014396 15.53312687
#  17.3502472  17.08302362  9.22665041  8.29671236  8.71892561 25.52728871
#  28.65380458 27.47802083 24.11100374 18.47258623 18.92686632 16.76235533
#  16.73563297 26.94357367 25.847957   29.19894068 20.34315128 22.48093991
#  18.20536265 22.4274952 ]

# %%
data.plot(kind='scatter',
          x='wt',
          y='mpg',
          figsize=(9,9),
          color='black',
          xlim=(0,7))

plt.plot(data['wt'],
         y_pred,
         color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X, y = data['mpg'])
print('Intercept của mô hình:',model.intercept_)
print('Coeffient của mô hình:',model.coef_)
print('Độ chỉnh xác của mô hình:',model.score(X, y = data['mpg']))
# Out:
# Intercept của mô hình: 49.93081094945181
# Coeffient của mô hình: [-13.38033708   1.17108689]
# Độ chỉnh xác của mô hình: 0.8190613581384094

# %%
import numpy as np
range=np.arange(1.5,5.5,0.1)
x_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='wt',
          y='mpg',
          figsize=(9,9),
          color='black',
          xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# hàm bậc 3
model=linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,]).T
model.fit(X, y = data['mpg'])
print('Intercept của mô hình:',model.intercept_)
print('Coeffient của mô hình:',model.coef_)
print('Độ chỉnh xác của mô hình:',model.score(X, y = data['mpg']))
import numpy as np
range=np.arange(1.5,5.5,0.1)
x_range=pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='wt',
          y='mpg',
          figsize=(9,9),
          color='black',
          xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình: 48.40369622795221
# Coeffient của mô hình: [-11.82597602   0.68937919   0.04593618]
# Độ chỉnh xác của mô hình: 0.8191284628478992
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# tăng độ chính xác bằng cách thêm biến
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp']],y=data['mpg'])
print('Intercept:',model.intercept_)
print('Coefficient:',model.coef_)
print('Accuracy:',model.score(X=data.loc[:,['wt','hp']],y=data['mpg']))
# Out:
# Intercept: 37.227270116447215
# Coefficient: [-3.87783074 -0.03177295]
# Accuracy: 0.8267854518827914

# %%
# tăng độ chính xác bằng cách thêm biến
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']],y=data['mpg'])
print('Intercept:',model.intercept_)
print('Coefficient:',model.coef_)
print('Accuracy:',model.score(X=data.loc[:,['wt','hp','disp']],y=data['mpg']))
# Out:
# Intercept: 37.10550526903184
# Coefficient: [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# Accuracy: 0.8268361424946447

# %% [markdown]
# # 50_Startups.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
url ='50_Startups.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation=data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
# Model Linear Regression
model = linear_model.LinearRegression()
# Teaching Machine
model.fit(X = pd.DataFrame(data['R&D Spend']), y = data['Profit'])
print('Hệ số intercept là: ',model.intercept_)
print('Hệ số coefient là: ', model.coef_)
# Out:
# Hệ số intercept là:  49032.89914125215
# Hệ số coefient là:  [0.85429137]

# %%
model.score(X = pd.DataFrame(data['R&D Spend']), y = data['Profit'])
# Out:
# 0.9465353160804393

# %%
y_pred=model.predict(X = pd.DataFrame(data['R&D Spend']))
print(y_pred)
# Out:
# [190289.29389289 187938.71118575 180116.65707807 172369.00320589
#  170433.97345032 161694.19683741 164033.72501421 160345.46724972
#  152011.33380847 154396.82286103 136096.36397105 135036.08586475
#  129219.89081021 127621.20411029 151499.37407569 146869.43093301
#  115678.82583435 129897.69412683 127413.41482014 122860.50313037
#  114175.91374003 116000.34693472 112245.81324567 106725.35677792
#  114850.93206678 104275.40289851 113385.70276482 110633.79960036
#  105460.14271464 105079.09459155 101994.24845109 101261.18102569
#  103202.54108032  96440.90176556  88694.29012885  88342.27936946
#   73520.10196791  86681.47714396  66314.86331588  81973.10151051
#   73597.47513738  72861.58000754  69229.14164122  62279.31048036
#   67979.15105018  49887.38699921  50156.68526807  49032.89914125
#   49495.96777887  49032.89914125]

# %%
data.plot(kind='scatter',
          x='R&D Spend',
          y='Profit',
          figsize=(9,9),
          color='black',
          )

plt.plot(data['R&D Spend'],
         y_pred,
         color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
'''X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,
                data['R&D Spend']**3,data['R&D Spend']**4,
                data['R&D Spend']**5,data['R&D Spend']**6,
                data['R&D Spend']**7,data['R&D Spend']**8,
                data['R&D Spend']**9,data['R&D Spend']**10]).T'''
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T        
model.fit(X, y = data['Profit'])
print('Intercept của mô hình:',model.intercept_)
print('Coeffient của mô hình:',model.coef_)
print('Độ chỉnh xác của mô hình:',model.score(X, y = data['Profit']))
# Out:
# Intercept của mô hình: 43108.76756818297
# Coeffient của mô hình: [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Độ chỉnh xác của mô hình: 0.9540709421464032

# %%
range=np.arange(0,150000,10)
x_range=pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='R&D Spend',
          y='Profit',
          figsize=(9,9),
          color='black'
          )
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# # Advertising.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
url ='Advertising.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.hist()
plt.show()

# %%
correlation=data.corr()
print(correlation)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
# Model Linear Regression
model = linear_model.LinearRegression()
# Teaching Machine
model.fit(X = pd.DataFrame(data['TV']), y = data['sales'])
print('Hệ số intercept là: ',model.intercept_)
print('Hệ số coefient là: ', model.coef_)
# Out:
# Hệ số intercept là:  7.032593549127695
# Hệ số coefient là:  [0.04753664]

# %%
model.score(X = pd.DataFrame(data['TV']), y = data['sales'])
# Out:
# 0.611875050850071

# %%
# hàm bậc 3
model=linear_model.LinearRegression()
X=pd.DataFrame([data['TV'],data['TV']**2]).T
model.fit(X, y = data['sales'])
print('Intercept của mô hình:',model.intercept_)
print('Coeffient của mô hình:',model.coef_)
print('Độ chỉnh xác của mô hình:',model.score(X, y = data['sales']))
import numpy as np
range=np.arange(10,200,10)
x_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=x_range)
data.plot(kind='scatter',
          x='TV',
          y='sales',
          figsize=(9,9),
          color='black',
          )
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình: 6.1141201283331075
# Coeffient của mô hình: [ 6.72659270e-02 -6.84693373e-05]
# Độ chỉnh xác của mô hình: 0.6190371168872755
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
